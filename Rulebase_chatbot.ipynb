# %%
import random

intents = {
    "greetings": [
        "hi", "hello", "good morning", "wasup", "hiii", "hey there", "good afternoon", "good evening"
    ],
    "time": [
        "working", "hour", "long", "time", "when do you open", "opening hours", "business time"
    ],
    "closing": [
        "bye", "see you soon", "have a nice day", "goodbye", "thanks, bye", "talk to you later"
    ],
    "inquire_services": [
        "what services do you offer", "tell me about your services", "what do you do",
        "what is your company about", "describe your services", "do you provide shipping", "import export service"
    ],
    "ask_exported_products": [
        "what items do you export", "what products do you sell", "what do you export",
        "exported goods", "products available for export", "export list", "items you trade"
    ],
    "ask_quality_standards": [
        "how do you ensure quality", "product quality", "are products certified",
        "do you follow standards", "quality check", "product certification", "quality assurance"
    ],
    "contact_info": [
        "how can I contact you", "what is your email", "give me your phone number",
        "customer support", "company contact", "reach you", "how to contact"
    ],
    "request_product": [
        "i want to import", "can you export to my country", "i need product details",
        "i want to request a shipment", "send me your product list", "request product import export",
        "place order", "submit product request"
    ],
    "general_help": [
        "i need help", "can you assist me", "what should i do",
        "how to begin", "not sure where to start", "guide me"
    ]
}

responses = {
    "greetings": [
        "Hello sir, my name is Alan. How can I help you?",
        "Guten Abend",
        "Hi there! How can I assist you today?"
    ],
    "time": [
        "We work from 9 AM to 9 PM.",
        "We are open from 9 AM to 9 PM.",
        "Our working hours are 9 AM to 9 PM, Monday to Saturday."
    ],
    "closing": [
        "Thank you for asking.",
        "Bye!",
        "See you soon.",
        "I hope I was of service to you. Goodbye!"
    ],
    "inquire_services": [
        "We specialize in import and export of high-quality goods across various sectors. Our services include international sourcing, logistics support, customs clearance, product quality checks, and global distribution.",
        "We offer global import-export solutions including procurement, warehousing, shipping, and customs support."
    ],
    "ask_exported_products": [
        "We export a wide range of products including agricultural goods (like spices, grains, and pulses), textiles, handicrafts, industrial machinery, and FMCG items.",
        "Our product list covers food items, garments, industrial tools, and raw materials. Would you like details for a specific category?"
    ],
    "ask_quality_standards": [
        "All our exports go through strict quality checks and comply with international standards.",
        "Yes, our products are certified and inspected thoroughly. We provide ISO, FSSAI, or other necessary certifications based on the product."
    ],
    "contact_info": [
        "You can contact us at info@yourexportco.com or call +1-234-567-890.",
        "Reach us anytime via our website contact form or email. We're here Monday to Saturday, 9 AM – 6 PM IST."
    ],
    "request_product": [
        "Please share the product name, quantity, destination country, and any specific requirements. Our team will respond shortly.",
        "Sure! Let us know what you need, and we’ll get back to you with a quote and shipping details."
    ],
    "general_help": [
        "I'm here to help! Ask me about services, products, or how to get started with a shipment.",
        "You can ask about what we export, our quality checks, how to place a request, or get in touch with us."
    ]
}

print("🤖 Alan the Chatbot - Import Export Assistant")

while True:
    user_input = input("You: ").lower()

    matched_intent = None
    for intent, phrases in intents.items():
        for phrase in phrases:
            if phrase in user_input:
                matched_intent = intent
                break
        if matched_intent:
            break

    if matched_intent:
        print("Alan:", random.choice(responses[matched_intent]))
    else:
        print("Alan: Sorry, I didn’t understand that. Could you rephrase or ask about our services or products?")
# Out:
# 🤖 Alan the Chatbot - Import Export Assistant
# Alan: We work from 9 AM to 9 PM.
# Alan: Our product list covers food items, garments, industrial tools, and raw materials. Would you like details for a specific category?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 86
#      83 print("🤖 Alan the Chatbot - Import Export Assistant")
#      85 while True:
# ---> 86     user_input = input("You: ").lower()
#      88     matched_intent = None
#      89     for intent, phrases in intents.items():
#
# File /media/hoax/91 PD/Projects/Projects/Python/Chatbot/venv-python/lib/python3.12/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
# ...
